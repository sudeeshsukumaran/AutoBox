# %% [markdown]
# <a href="https://colab.research.google.com/github/sudeeshsukumaran/AutoBox/blob/main/FaceDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.1 MB 25 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=31609510d489a2c73adebd62f6a94495b0da5f02a0e4e982a181d0f25cf13302
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
from imutils import paths #imutils includes opencv functions
import face_recognition
import pickle
import cv2
import os
import glob

# %%
#https://github.com/sudeeshsukumaran/AutoBox/blob/main/Images/Train/Angelina_Jolie/Angelina_Jolie_0002.jpg

#get paths of each file in folder named Images
#Images here that contains data(folders of various people)
imagePath = 'https://github.com/sudeeshsukumaran/AutoBox/blob/main/Images/Train/Angelina_Jolie/' #list(paths.list_images('Images'))
kEncodings = []
kNames = []

# %%
print("IMG PATH = ", imagePath)
# Out:
# IMG PATH =  https://github.com/sudeeshsukumaran/AutoBox/blob/main/Images/Train/Angelina_Jolie/

# %%
#path = os.path.join(cur_direc, 'data/faces/')
print(imagePath+'*.jpg')
print(glob.glob(imagePath+'*.jpg'))
for f in glob.glob(imagePath+'*.*'):
  print(f)

list_of_files = [f for f in glob.glob(imagePath+'*.jpg')]
print("Number of Images = ", len(list_of_files))
# Out:
# https://github.com/sudeeshsukumaran/AutoBox/blob/main/Images/Train/Angelina_Jolie/*.jpg
# []
# Number of Images =  0

# %%
# !git clone https://github.com/sudeeshsukumaran/AutoBox.git images
from PIL import Image
Image.open('images/Images/Train/Angelina_Jolie/Angelina_Jolie_0003.jpg')
# Out:
# fatal: destination path 'images' already exists and is not an empty directory.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x7FF8ADA3F410>
